# %% [markdown]
# # Dependencies/setup
# To begin, prepare the colab environment by clicking the play button below and make sure you are using a GPU runtime. This will install all dependencies for the future code. This can take up to 1.5 minutes.

# %%
# !mkdir -p /usr/share/vulkan/icd.d
# !wget -q https://raw.githubusercontent.com/haosulab/ManiSkill2/main/docker/nvidia_icd.json
# !wget -q https://raw.githubusercontent.com/haosulab/ManiSkill2/main/docker/10_nvidia.json
# !mv nvidia_icd.json /usr/share/vulkan/icd.d
# !mv 10_nvidia.json /usr/share/glvnd/egl_vendor.d/10_nvidia.json
# dependencies
# !apt-get install -y --no-install-recommends libvulkan-dev
# !pip install git+https://github.com/arnavg115/ManiSkill2.git
# !pip install --upgrade --no-cache-dir gdown
# !pip install transformers wandb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libvulkan1
# Recommended packages:
#   mesa-vulkan-drivers | vulkan-icd
# The following NEW packages will be installed:
#   libvulkan-dev libvulkan1
# 0 upgraded, 2 newly installed, 0 to remove and 23 not upgraded.
# Need to get 1,020 kB of archives.
# After this operation, 17.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvulkan1 amd64 1.3.204.1-2 [128 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvulkan-dev amd64 1.3.204.1-2 [892 kB]
# Fetched 1,020 kB in 1s (1,278 kB/s)
# Selecting previously unselected package libvulkan1:amd64.
# (Reading database ... 120903 files and directories currently installed.)
# Preparing to unpack .../libvulkan1_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan1:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package libvulkan-dev:amd64.
# Preparing to unpack .../libvulkan-dev_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan-dev:amd64 (1.3.204.1-2) ...
# Setting up libvulkan1:amd64 (1.3.204.1-2) ...
# Setting up libvulkan-dev:amd64 (1.3.204.1-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Collecting git+https://github.com/arnavg115/ManiSkill2.git
#   Cloning https://github.com/arnavg115/ManiSkill2.git to /tmp/pip-req-build-6fwo8h7u
#   Running command git clone --filter=blob:none --quiet https://github.com/arnavg115/ManiSkill2.git /tmp/pip-req-build-6fwo8h7u
#   Resolved https://github.com/arnavg115/ManiSkill2.git to commit d7e90358ee5b28e969eb254b0108bb925f8fd8a9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<1.24 in /usr/local/lib/python3.10/dist-packages (from mani-skill2==0.6.0) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mani-skill2==0.6.0) (1.11.4)
# Collecting gymnasium>=0.28.1 (from mani-skill2==0.6.0)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 9.6 MB/s eta 0:00:00
# Collecting sapien==3.0.0.dev0 (from mani-skill2==0.6.0)
#   Downloading sapien-3.0.0.dev0-cp310-cp310-manylinux2014_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from mani-skill2==0.6.0) (3.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mani-skill2==0.6.0) (6.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mani-skill2==0.6.0) (4.66.1)
# Collecting GitPython (from mani-skill2==0.6.0)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from mani-skill2==0.6.0) (0.9.0)
# Requirement already satisfied: gdown>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from mani-skill2==0.6.0) (4.6.6)
# Collecting transforms3d (from mani-skill2==0.6.0)
#   Downloading transforms3d-0.4.1-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 86.4 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from mani-skill2==0.6.0) (4.8.0.76)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from mani-skill2==0.6.0) (2.31.6)
# Collecting trimesh (from mani-skill2==0.6.0)
#   Downloading trimesh-4.0.5-py3-none-any.whl (688 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.5/688.5 kB 57.1 MB/s eta 0:00:00
# Collecting rtree (from mani-skill2==0.6.0)
#   Downloading Rtree-1.1.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (488 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 51.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.10/dist-packages (from sapien==3.0.0.dev0->mani-skill2==0.6.0) (2.31.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sapien==3.0.0.dev0->mani-skill2==0.6.0) (4.9.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from sapien==3.0.0.dev0->mani-skill2==0.6.0) (3.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=4.6.0->mani-skill2==0.6.0) (3.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown>=4.6.0->mani-skill2==0.6.0) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.6.0->mani-skill2==0.6.0) (4.11.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.1->mani-skill2==0.6.0) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.1->mani-skill2==0.6.0) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium>=0.28.1->mani-skill2==0.6.0)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting gitdb<5,>=4.0.1 (from GitPython->mani-skill2==0.6.0)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio->mani-skill2==0.6.0) (9.4.0)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.10/dist-packages (from imageio->mani-skill2==0.6.0) (0.4.9)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from imageio->mani-skill2==0.6.0) (5.9.5)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython->mani-skill2==0.6.0)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->sapien==3.0.0.dev0->mani-skill2==0.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->sapien==3.0.0.dev0->mani-skill2==0.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->sapien==3.0.0.dev0->mani-skill2==0.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->sapien==3.0.0.dev0->mani-skill2==0.6.0) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.6.0->mani-skill2==0.6.0) (2.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg->imageio->mani-skill2==0.6.0) (67.7.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->sapien==3.0.0.dev0->mani-skill2==0.6.0) (1.7.1)
# Building wheels for collected packages: mani-skill2
#   Building wheel for mani-skill2 (pyproject.toml) ... done
#   Created wheel for mani-skill2: filename=mani_skill2-0.6.0-py3-none-any.whl size=12012239 sha256=367a6325b4de4e0b108b35a5d1a49585c40318e13ed3b433ab196e1b867402e9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-34syf3um/wheels/1e/95/3f/a14059058deb304173a0da5324e81e4ef30ff2e1858476a4c7
# Successfully built mani-skill2
# Installing collected packages: farama-notifications, trimesh, transforms3d, smmap, rtree, gymnasium, sapien, gitdb, GitPython, mani-skill2
# Successfully installed GitPython-3.1.40 farama-notifications-0.0.4 gitdb-4.0.11 gymnasium-0.29.1 mani-skill2-0.6.0 rtree-1.1.0 sapien-3.0.0.dev0 smmap-5.0.1 transforms3d-0.4.1 trimesh-4.0.5
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# Successfully installed gdown-4.7.1

# %%
try:
    import google.colab

    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    import site

    site.main()

# %% [markdown]
# # Applying Decision Transformers to ManiSkill2
#
#
# This notebook implements the [decision transformer](https://sites.google.com/berkeley.edu/decision-transformer) model and applies it to some of the environments from [maniskill2](https://maniskill2.github.io/).

# %%
# make all the important imports
import gymnasium as gym
import numpy as np
import h5py
import torch
import torch.nn as nn
from tqdm.notebook import tqdm
import mani_skill2.envs
from mani_skill2.utils.wrappers import RecordEpisode
from torch.utils.data import Dataset
import wandb
import random
import os
# Out:
# /usr/local/lib/python3.10/dist-packages/sapien/wrapper/pinocchio_model.py:281: UserWarning: pinnochio package is not installed, fallback to built-in pinocchio
#   warnings.warn(

# %% [markdown]
# # 0. Initialize environment and download dataset.
# The origiinal decision transformers paper uses offline reinforcement learning. This form of reinforcement learning uses recorded trajectories of other policies in order to learn. This is contrasted with online reinforcement learning since the model doesn't interact with the environment during training.
#
# In our case we download these recorded trajectories. However, these trajectories don't contain reward data. So we then use the replay trajectory feature of Maniskill2 to also save these rewards.

# %%
# @markdown Specifies which environment is used.
env_id = "LiftCube-v0"  # @param ["PickCube-v0", "LiftCube-v0", "StackCube-v0"]

# %%
# init env
env = gym.make(env_id, obs_mode="state", control_mode="pd_ee_delta_pose")

# %%
# download the trajectories
# !python -m mani_skill2.utils.download_demo {env_id} -o demos
# Out:
# Downloading v0 demonstrations: 1/1, LiftCube-v0
# 3.08Mit [00:01, 2.07Mit/s]
# 32.8kit [00:00, 135kit/s]

# %%
# replay trajectories and save the reward data.
# !python -m mani_skill2.trajectory.replay_trajectory --traj-path \
    demos/v0/rigid_body/{env_id}/trajectory.h5 --save-traj \
    --obs-mode state --target-control-mode pd_ee_delta_pose --num-procs 2 --record-reward true
# Out:
# /usr/local/lib/python3.10/dist-packages/sapien/wrapper/pinocchio_model.py:281: UserWarning: pinnochio package is not installed, fallback to built-in pinocchio
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sapien/wrapper/pinocchio_model.py:281: UserWarning: pinnochio package is not installed, fallback to built-in pinocchio
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sapien/wrapper/pinocchio_model.py:281: UserWarning: pinnochio package is not installed, fallback to built-in pinocchio
#   warnings.warn(
# 0step [00:00, ?step/s][2023-12-12 22:33:28.901] [svulkan2] [error] GLFW error: X11: The DISPLAY environment variable is missing. You may suppress this message by setting environment variable SAPIEN_NO_DISPLAY=1
# [2023-12-12 22:33:28.901] [svulkan2] [warning] Failed to initialize GLFW. Display is disabled.
# [2023-12-12 22:33:29.135] [svulkan2] [error] GLFW error: The GLFW library is not initialized. You may suppress this message by setting environment variable SAPIEN_NO_DISPLAY=1
#
# 0step [00:00, ?step/s][2023-12-12 22:33:29.672] [svulkan2] [error] GLFW error: X11: The DISPLAY environment variable is missing. You may suppress this message by setting environment variable SAPIEN_NO_DISPLAY=1
# [2023-12-12 22:33:29.672] [svulkan2] [warning] Failed to initialize GLFW. Display is disabled.
# [2023-12-12 22:33:29.826] [svulkan2] [error] GLFW error: The GLFW library is not initialized. You may suppress this message by setting environment variable SAPIEN_NO_DISPLAY=1
# 0step [00:02, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]/usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.obs_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obs_mode` for environment variables or `env.get_wrapper_attr('obs_mode')` that will search the reminding wrappers.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.control_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.control_mode` for environment variables or `env.get_wrapper_attr('control_mode')` that will search the reminding wrappers.
#   logger.warn(
# 2023-12-12 22:33:31,112 - mani_skill2 - WARNING - mani_skill2 is not installed with git.
# Replaying traj_0:   0% 0/89 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]/usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.agent to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.agent` for environment variables or `env.get_wrapper_attr('agent')` that will search the reminding wrappers.
#   logger.warn(
# Replaying traj_0:  16% 14/89 [00:00<00:01, 52.09step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# 0step [00:01, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]/usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.obs_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obs_mode` for environment variables or `env.get_wrapper_attr('obs_mode')` that will search the reminding wrappers.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.control_mode to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.control_mode` for environment variables or `env.get_wrapper_attr('control_mode')` that will search the reminding wrappers.
#   logger.warn(
# Replaying traj_0:  22% 20/89 [00:00<00:01, 49.82step/s, control_mode=pd_ee_delta_pose, obs_mode=state]2023-12-12 22:33:31,519 - mani_skill2 - WARNING - mani_skill2 is not installed with git.
#
# Replaying traj_50: : 0step [00:01, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_50:   0% 0/83 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]/usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.agent to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.agent` for environment variables or `env.get_wrapper_attr('agent')` that will search the reminding wrappers.
#   logger.warn(
#
# Replaying traj_0:  29% 26/89 [00:00<00:01, 47.15step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  42% 37/89 [00:00<00:01, 47.53step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  47% 42/89 [00:01<00:01, 33.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_50:  31% 26/83 [00:00<00:02, 28.39step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  52% 46/89 [00:01<00:01, 23.75step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  56% 50/89 [00:01<00:02, 16.33step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_50:  45% 37/83 [00:01<00:02, 18.35step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  60% 53/89 [00:01<00:02, 16.29step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  66% 59/89 [00:02<00:01, 18.79step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  71% 63/89 [00:02<00:01, 20.63step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_50:  60% 50/83 [00:02<00:01, 21.54step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  74% 66/89 [00:02<00:01, 18.18step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  81% 72/89 [00:02<00:00, 19.68step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  84% 75/89 [00:03<00:00, 19.71step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  88% 78/89 [00:03<00:00, 19.51step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  91% 81/89 [00:03<00:00, 20.97step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  94% 84/89 [00:03<00:00, 20.88step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_50:  84% 70/83 [00:03<00:00, 18.65step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_0:  98% 87/89 [00:03<00:00, 19.97step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:   0% 0/84 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:   6% 5/84 [00:00<00:02, 37.70step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  11% 9/84 [00:00<00:02, 35.87step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  17% 14/84 [00:00<00:01, 38.30step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_51: 100% 83/83 [00:03<00:00, 19.89step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  21% 18/84 [00:00<00:01, 36.49step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  26% 22/84 [00:00<00:01, 37.45step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  38% 32/84 [00:00<00:01, 41.13step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  44% 37/84 [00:01<00:01, 34.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_51:  27% 25/94 [00:00<00:01, 37.24step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_51:  31% 29/94 [00:00<00:01, 36.78step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_51:  35% 33/94 [00:00<00:01, 31.73step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  52% 44/84 [00:01<00:02, 19.82step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_51:  44% 41/94 [00:01<00:01, 29.67step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  56% 47/84 [00:01<00:02, 16.64step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  60% 50/84 [00:02<00:02, 16.39step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  63% 53/84 [00:02<00:01, 18.28step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  69% 58/84 [00:02<00:01, 17.37step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  71% 60/84 [00:02<00:01, 17.44step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  75% 63/84 [00:02<00:01, 19.85step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  79% 66/84 [00:02<00:01, 17.33step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_51:  71% 67/94 [00:02<00:01, 21.24step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  81% 68/84 [00:02<00:00, 17.18step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  87% 73/84 [00:03<00:00, 17.12step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  90% 76/84 [00:03<00:00, 19.73step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  94% 79/84 [00:03<00:00, 19.11step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_1:  99% 83/84 [00:03<00:00, 22.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2: 100% 84/84 [00:03<00:00, 22.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:   5% 4/87 [00:00<00:02, 38.84step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_51:  99% 93/94 [00:03<00:00, 24.46step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_52: 100% 94/94 [00:03<00:00, 24.46step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:   9% 8/87 [00:00<00:02, 35.34step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  14% 12/87 [00:00<00:02, 36.60step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  18% 16/87 [00:00<00:01, 35.55step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  23% 20/87 [00:00<00:01, 36.37step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  32% 28/87 [00:00<00:01, 31.35step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  37% 32/87 [00:01<00:02, 26.33step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  40% 35/87 [00:01<00:02, 20.64step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  44% 38/87 [00:01<00:02, 16.82step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  48% 42/87 [00:02<00:03, 12.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  51% 44/87 [00:02<00:04, 10.60step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  53% 46/87 [00:02<00:03, 10.75step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  55% 48/87 [00:02<00:03, 10.35step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_52:  53% 48/90 [00:02<00:03, 11.94step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  60% 52/87 [00:02<00:02, 12.10step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_52:  59% 53/90 [00:02<00:02, 15.04step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  62% 54/87 [00:03<00:02, 13.42step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  64% 56/87 [00:03<00:02, 13.53step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  70% 61/87 [00:03<00:01, 17.33step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  74% 64/87 [00:03<00:01, 18.71step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  76% 66/87 [00:03<00:01, 18.67step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  80% 70/87 [00:03<00:00, 17.85step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  83% 72/87 [00:04<00:00, 17.76step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  85% 74/87 [00:04<00:00, 17.40step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  87% 76/87 [00:04<00:00, 17.20step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  90% 78/87 [00:04<00:00, 17.81step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  94% 82/87 [00:04<00:00, 23.31step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_52:  93% 84/90 [00:04<00:00, 16.97step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_2:  98% 85/87 [00:04<00:00, 21.91step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:   0% 0/80 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_53: 100% 90/90 [00:04<00:00, 18.88step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  12% 10/80 [00:00<00:01, 46.13step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_53:   5% 5/91 [00:00<00:02, 40.27step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  25% 20/80 [00:00<00:01, 42.32step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  31% 25/80 [00:00<00:01, 42.14step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  38% 30/80 [00:00<00:01, 40.35step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  44% 35/80 [00:00<00:01, 38.46step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  49% 39/80 [00:01<00:01, 32.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  54% 43/80 [00:01<00:01, 31.10step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  59% 47/80 [00:01<00:01, 31.62step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  64% 51/80 [00:01<00:00, 32.56step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  69% 55/80 [00:01<00:00, 33.89step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  74% 59/80 [00:01<00:00, 34.72step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  79% 63/80 [00:01<00:00, 35.75step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  84% 67/80 [00:01<00:00, 36.32step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  89% 71/80 [00:01<00:00, 35.18step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_3:  94% 75/80 [00:02<00:00, 35.76step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:   0% 0/90 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:   9% 8/90 [00:00<00:01, 77.57step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  18% 16/90 [00:00<00:00, 77.31step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  28% 25/90 [00:00<00:00, 79.91step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_54: 100% 91/91 [00:02<00:00, 36.37step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  37% 33/90 [00:00<00:00, 72.22step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  46% 41/90 [00:00<00:00, 64.41step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_54:  20% 16/82 [00:00<00:00, 75.03step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  53% 48/90 [00:00<00:00, 52.19step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  60% 54/90 [00:00<00:00, 44.91step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  66% 59/90 [00:01<00:00, 41.49step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  71% 64/90 [00:01<00:00, 38.98step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  81% 73/90 [00:01<00:00, 36.22step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  86% 77/90 [00:01<00:00, 35.83step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_54:  72% 59/82 [00:01<00:00, 37.53step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  90% 81/90 [00:01<00:00, 34.54step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_4:  99% 89/90 [00:02<00:00, 34.78step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:   0% 0/91 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:   9% 8/91 [00:00<00:01, 79.73step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  18% 16/91 [00:00<00:00, 77.70step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_55: 100% 82/82 [00:01<00:00, 35.75step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  27% 25/91 [00:00<00:00, 79.94step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  36% 33/91 [00:00<00:00, 70.93step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_55:  20% 18/88 [00:00<00:00, 79.59step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  45% 41/91 [00:00<00:00, 60.54step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  53% 48/91 [00:00<00:00, 47.72step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  59% 54/91 [00:01<00:00, 42.45step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  65% 59/91 [00:01<00:00, 38.14step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  70% 64/91 [00:01<00:00, 36.61step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  75% 68/91 [00:01<00:00, 35.72step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  79% 72/91 [00:01<00:00, 35.42step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  84% 76/91 [00:01<00:00, 34.65step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  88% 80/91 [00:01<00:00, 33.31step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  92% 84/91 [00:01<00:00, 33.07step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_5:  97% 88/91 [00:02<00:00, 34.13step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:   0% 0/93 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:   9% 8/93 [00:00<00:01, 75.64step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_56: 100% 88/88 [00:02<00:00, 34.90step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  17% 16/93 [00:00<00:00, 77.28step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  26% 24/93 [00:00<00:00, 76.17step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  34% 32/93 [00:00<00:00, 67.45step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  42% 39/93 [00:00<00:00, 61.91step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_56:  36% 32/89 [00:00<00:00, 66.55step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  49% 46/93 [00:00<00:00, 48.97step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  56% 52/93 [00:00<00:00, 43.23step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  61% 57/93 [00:01<00:00, 40.00step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  71% 66/93 [00:01<00:00, 37.30step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  75% 70/93 [00:01<00:00, 36.49step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  80% 74/93 [00:01<00:00, 35.76step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  84% 78/93 [00:01<00:00, 35.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  88% 82/93 [00:01<00:00, 34.99step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  92% 86/93 [00:01<00:00, 34.41step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_6:  98% 91/93 [00:02<00:00, 36.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_56: 100% 89/89 [00:01<00:00, 36.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_57: 100% 89/89 [00:01<00:00, 36.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:   0% 0/94 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:   9% 8/94 [00:00<00:01, 75.54step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  17% 16/94 [00:00<00:01, 74.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  26% 24/94 [00:00<00:00, 74.94step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  34% 32/94 [00:00<00:00, 66.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  48% 45/94 [00:00<00:00, 53.24step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  54% 51/94 [00:00<00:00, 46.20step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  60% 56/94 [00:01<00:00, 41.66step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  65% 61/94 [00:01<00:00, 39.62step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_57:  70% 61/87 [00:01<00:00, 39.81step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  74% 70/94 [00:01<00:00, 36.72step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_57:  82% 71/87 [00:01<00:00, 37.99step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  79% 74/94 [00:01<00:00, 34.96step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  83% 78/94 [00:01<00:00, 34.69step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  87% 82/94 [00:01<00:00, 34.99step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_58: 100% 87/87 [00:01<00:00, 37.18step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  91% 86/94 [00:01<00:00, 34.55step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_7:  96% 90/94 [00:02<00:00, 34.49step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:   0% 0/107 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  15% 16/107 [00:00<00:01, 70.76step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  29% 31/107 [00:00<00:01, 64.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  36% 38/107 [00:00<00:01, 52.31step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  46% 49/107 [00:00<00:01, 41.00step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  55% 59/107 [00:01<00:01, 40.67step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  60% 64/107 [00:01<00:01, 33.30step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  64% 68/107 [00:01<00:01, 29.63step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  67% 72/107 [00:01<00:01, 27.86step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  70% 75/107 [00:01<00:01, 27.23step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  78% 83/107 [00:02<00:00, 30.88step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  81% 87/107 [00:02<00:00, 32.86step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  86% 92/107 [00:02<00:00, 35.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  90% 96/107 [00:02<00:00, 35.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8:  94% 101/107 [00:02<00:00, 36.70step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_8: 100% 107/107 [00:02<00:00, 40.84step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Episode 8 is not replayed successfully. Skipping
# Replaying traj_9:   0% 0/90 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_58: 100% 84/84 [00:03<00:00, 19.78step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_59: 100% 84/84 [00:03<00:00, 19.78step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  13% 12/90 [00:00<00:01, 53.25step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  20% 18/90 [00:00<00:01, 53.61step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_59:  10% 10/103 [00:00<00:02, 44.05step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  27% 24/90 [00:00<00:01, 47.60step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  33% 30/90 [00:00<00:01, 50.52step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  40% 36/90 [00:00<00:01, 43.31step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  46% 41/90 [00:00<00:01, 35.44step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_59:  38% 39/103 [00:00<00:01, 41.03step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  50% 45/90 [00:01<00:01, 29.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  54% 49/90 [00:01<00:01, 24.79step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  58% 52/90 [00:01<00:01, 23.96step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  61% 55/90 [00:01<00:01, 22.49step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  64% 58/90 [00:01<00:01, 21.12step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  71% 64/90 [00:02<00:01, 21.27step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  74% 67/90 [00:02<00:01, 22.81step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_59:  70% 72/103 [00:02<00:01, 23.57step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  78% 70/90 [00:02<00:00, 20.81step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  81% 73/90 [00:02<00:00, 20.43step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_59:  80% 82/103 [00:02<00:00, 26.87step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  87% 78/90 [00:02<00:00, 19.23step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_9:  91% 82/90 [00:03<00:00, 22.40step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:   0% 0/91 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:   8% 7/91 [00:00<00:01, 69.56step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  16% 15/91 [00:00<00:01, 74.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_60: 100% 103/103 [00:03<00:00, 24.53step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  25% 23/91 [00:00<00:01, 66.83step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_60:   8% 8/102 [00:00<00:01, 73.69step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  33% 30/91 [00:00<00:00, 65.15step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  41% 37/91 [00:00<00:00, 60.89step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  48% 44/91 [00:00<00:00, 53.42step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  55% 50/91 [00:00<00:00, 46.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  60% 55/91 [00:01<00:00, 43.05step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  66% 60/91 [00:01<00:00, 39.21step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  76% 69/91 [00:01<00:00, 36.47step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  80% 73/91 [00:01<00:00, 36.99step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  85% 77/91 [00:01<00:00, 36.28step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  89% 81/91 [00:01<00:00, 35.65step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  93% 85/91 [00:01<00:00, 35.80step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_10:  98% 89/91 [00:02<00:00, 35.92step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:   0% 0/87 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:   9% 8/87 [00:00<00:00, 79.30step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  18% 16/87 [00:00<00:00, 73.36step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  28% 24/87 [00:00<00:00, 74.46step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_61: 100% 102/102 [00:02<00:00, 38.25step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_61:   0% 0/93 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  37% 32/87 [00:00<00:00, 61.54step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_61:  14% 13/93 [00:00<00:01, 63.77step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  45% 39/87 [00:00<00:00, 52.76step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  52% 45/87 [00:00<00:00, 45.51step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  57% 50/87 [00:00<00:00, 42.07step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  63% 55/87 [00:01<00:00, 39.21step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  74% 64/87 [00:01<00:00, 37.10step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  78% 68/87 [00:01<00:00, 36.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  83% 72/87 [00:01<00:00, 34.45step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  87% 76/87 [00:01<00:00, 35.28step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  92% 80/87 [00:01<00:00, 35.50step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_11:  97% 84/87 [00:01<00:00, 36.27step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:   0% 0/86 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:   9% 8/86 [00:00<00:01, 71.20step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  19% 16/86 [00:00<00:00, 72.80step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  28% 24/86 [00:00<00:00, 73.07step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_62: 100% 93/93 [00:02<00:00, 37.53step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_62:   0% 0/98 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  37% 32/86 [00:00<00:00, 65.49step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  45% 39/86 [00:00<00:00, 53.36step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  52% 45/86 [00:00<00:00, 48.47step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_62:  34% 33/98 [00:00<00:00, 72.21step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  65% 56/86 [00:01<00:00, 41.28step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  71% 61/86 [00:01<00:00, 39.53step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  77% 66/86 [00:01<00:00, 39.81step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  83% 71/86 [00:01<00:00, 40.20step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  88% 76/86 [00:01<00:00, 38.11step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_12:  99% 85/86 [00:01<00:00, 39.39step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:   0% 0/92 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:   9% 8/92 [00:00<00:01, 77.61step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  26% 24/92 [00:00<00:00, 69.51step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  34% 31/92 [00:00<00:00, 68.09step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  41% 38/92 [00:00<00:00, 63.78step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_62:  97% 95/98 [00:02<00:00, 34.26step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_63: 100% 98/98 [00:02<00:00, 34.26step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  49% 45/92 [00:00<00:00, 54.60step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  55% 51/92 [00:00<00:00, 45.66step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_63:  19% 16/86 [00:00<00:00, 73.96step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  61% 56/92 [00:01<00:00, 39.98step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  66% 61/92 [00:01<00:00, 37.24step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  75% 69/92 [00:01<00:00, 35.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  79% 73/92 [00:01<00:00, 32.97step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  84% 77/92 [00:01<00:00, 33.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  88% 81/92 [00:01<00:00, 33.84step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  92% 85/92 [00:01<00:00, 33.50step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_13:  97% 89/92 [00:02<00:00, 34.40step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:   0% 0/91 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  18% 16/91 [00:00<00:01, 75.00step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_63:  87% 75/86 [00:01<00:00, 34.77step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  27% 25/91 [00:00<00:00, 77.90step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  36% 33/91 [00:00<00:00, 72.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_64: 100% 86/86 [00:02<00:00, 35.87step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  45% 41/91 [00:00<00:00, 66.25step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_64:   8% 7/90 [00:00<00:01, 65.63step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  53% 48/91 [00:00<00:00, 53.42step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_64:  26% 23/90 [00:00<00:00, 75.41step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  59% 54/91 [00:00<00:00, 45.00step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  65% 59/91 [00:01<00:00, 41.11step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  76% 69/91 [00:01<00:00, 37.13step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  80% 73/91 [00:01<00:00, 36.66step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  89% 81/91 [00:01<00:00, 33.41step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_64:  71% 64/90 [00:01<00:00, 36.19step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_14:  93% 85/91 [00:02<00:00, 26.86step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:   0% 0/92 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:   7% 6/92 [00:00<00:01, 55.66step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  13% 12/92 [00:00<00:01, 54.86step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  20% 18/92 [00:00<00:01, 44.11step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  25% 23/92 [00:00<00:01, 40.99step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  32% 29/92 [00:00<00:01, 43.35step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_65:   0% 0/93 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  37% 34/92 [00:00<00:01, 37.73step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  41% 38/92 [00:00<00:01, 34.60step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_65:  13% 12/93 [00:00<00:02, 37.87step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  46% 42/92 [00:01<00:01, 30.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_65:  24% 22/93 [00:00<00:01, 40.09step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  50% 46/92 [00:01<00:01, 25.33step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  53% 49/92 [00:01<00:01, 22.77step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  57% 52/92 [00:01<00:01, 21.05step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_65:  41% 38/93 [00:01<00:01, 31.12step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  60% 55/92 [00:01<00:01, 20.03step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  66% 61/92 [00:02<00:01, 19.39step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  71% 65/92 [00:02<00:01, 21.76step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_65:  57% 53/93 [00:01<00:01, 25.02step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  74% 68/92 [00:02<00:01, 20.55step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  77% 71/92 [00:02<00:01, 20.77step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  80% 74/92 [00:02<00:00, 20.39step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  84% 77/92 [00:02<00:00, 20.83step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  87% 80/92 [00:03<00:00, 19.44step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  91% 84/92 [00:03<00:00, 18.31step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15:  93% 86/92 [00:03<00:00, 18.48step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_15: 100% 92/92 [00:03<00:00, 22.75step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:   0% 0/88 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:   9% 8/88 [00:00<00:01, 65.46step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  17% 15/88 [00:00<00:01, 48.51step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  24% 21/88 [00:00<00:01, 46.31step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  30% 26/88 [00:00<00:01, 42.94step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_66: 100% 93/93 [00:03<00:00, 19.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_66:   0% 0/107 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  35% 31/88 [00:00<00:01, 36.19step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  40% 35/88 [00:00<00:01, 32.92step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  44% 39/88 [00:01<00:01, 29.58step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_66:  25% 27/107 [00:00<00:01, 51.89step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  49% 43/88 [00:01<00:01, 25.44step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  56% 49/88 [00:01<00:01, 26.15step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_66:  42% 45/107 [00:00<00:01, 43.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  59% 52/88 [00:01<00:01, 23.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  67% 59/88 [00:01<00:01, 26.61step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  72% 63/88 [00:02<00:00, 29.19step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  76% 67/88 [00:02<00:00, 31.10step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  81% 71/88 [00:02<00:00, 32.43step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  85% 75/88 [00:02<00:00, 33.58step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  90% 79/88 [00:02<00:00, 34.77step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_16:  94% 83/88 [00:02<00:00, 35.04step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:   0% 0/89 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  10% 9/89 [00:00<00:01, 79.60step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  19% 17/89 [00:00<00:00, 75.05step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  28% 25/89 [00:00<00:00, 73.34step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  37% 33/89 [00:00<00:00, 67.70step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_66:  98% 105/107 [00:02<00:00, 35.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_67: 100% 107/107 [00:02<00:00, 35.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  45% 40/89 [00:00<00:00, 55.35step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_67:   9% 8/88 [00:00<00:01, 72.27step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  52% 46/89 [00:00<00:00, 47.10step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  58% 52/89 [00:00<00:00, 42.90step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  64% 57/89 [00:01<00:00, 40.88step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  74% 66/89 [00:01<00:00, 37.59step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  79% 70/89 [00:01<00:00, 37.56step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  88% 78/89 [00:01<00:00, 36.56step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  92% 82/89 [00:01<00:00, 36.90step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_17:  97% 86/89 [00:01<00:00, 37.72step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:   8% 8/99 [00:00<00:01, 79.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  16% 16/99 [00:00<00:01, 72.95step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  24% 24/99 [00:00<00:01, 72.98step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  32% 32/99 [00:00<00:00, 74.03step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_67:  99% 87/88 [00:01<00:00, 35.12step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_68: 100% 88/88 [00:01<00:00, 35.12step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  40% 40/99 [00:00<00:00, 63.94step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  47% 47/99 [00:00<00:00, 59.20step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_68:  16% 16/100 [00:00<00:01, 76.55step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  55% 54/99 [00:00<00:00, 54.19step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  61% 60/99 [00:01<00:00, 46.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  66% 65/99 [00:01<00:00, 42.03step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  71% 70/99 [00:01<00:00, 37.69step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  79% 78/99 [00:01<00:00, 35.72step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  83% 82/99 [00:01<00:00, 35.19step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  91% 90/99 [00:01<00:00, 34.93step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  95% 94/99 [00:02<00:00, 35.10step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_18:  99% 98/99 [00:02<00:00, 35.98step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:   0% 0/89 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  18% 16/89 [00:00<00:00, 75.15step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_68:  86% 86/100 [00:01<00:00, 33.43step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  28% 25/89 [00:00<00:00, 78.27step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  37% 33/89 [00:00<00:00, 71.16step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  46% 41/89 [00:00<00:00, 62.56step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_69: 100% 100/100 [00:02<00:00, 36.04step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_69:   0% 0/91 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  54% 48/89 [00:00<00:00, 49.18step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_69:  18% 16/91 [00:00<00:01, 71.49step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  61% 54/89 [00:01<00:00, 42.53step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  66% 59/89 [00:01<00:00, 38.70step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  72% 64/89 [00:01<00:00, 37.61step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  81% 72/89 [00:01<00:00, 36.75step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  85% 76/89 [00:01<00:00, 36.97step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  90% 80/89 [00:01<00:00, 36.37step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_19:  99% 88/89 [00:01<00:00, 36.03step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:   0% 0/97 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:   8% 8/97 [00:00<00:01, 74.66step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  18% 17/97 [00:00<00:01, 79.67step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  26% 25/97 [00:00<00:00, 79.57step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  34% 33/97 [00:00<00:00, 78.11step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  42% 41/97 [00:00<00:00, 70.11step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  51% 49/97 [00:00<00:00, 66.04step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_70: 100% 91/91 [00:02<00:00, 36.37step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_70:   0% 0/90 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  58% 56/97 [00:00<00:00, 52.64step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  64% 62/97 [00:01<00:00, 44.36step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_70:  26% 23/90 [00:00<00:00, 69.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  69% 67/97 [00:01<00:00, 40.54step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  74% 72/97 [00:01<00:00, 39.20step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  84% 81/97 [00:01<00:00, 38.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  88% 85/97 [00:01<00:00, 37.09step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_20:  96% 93/97 [00:01<00:00, 36.60step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_21:   0% 0/88 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_21:   8% 7/88 [00:00<00:01, 69.47step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_21:  17% 15/88 [00:00<00:00, 73.09step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_21:  27% 24/88 [00:00<00:00, 77.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_21:  36% 32/88 [00:00<00:00, 72.91step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# ...
# Replaying traj_42:  60% 50/83 [00:00<00:00, 41.96step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_42:  66% 55/83 [00:01<00:00, 39.35step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_42:  72% 60/83 [00:01<00:00, 38.40step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_42:  77% 64/83 [00:01<00:00, 37.73step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_42:  82% 68/83 [00:01<00:00, 36.32step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_42:  87% 72/83 [00:01<00:00, 35.37step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_42:  92% 76/83 [00:01<00:00, 33.97step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_42:  96% 80/83 [00:01<00:00, 33.94step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_92:  96% 92/96 [00:01<00:00, 61.54step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Episode 92 is not replayed successfully. Skipping
#
# Replaying traj_92: 100% 96/96 [00:01<00:00, 61.54step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_93: 100% 96/96 [00:01<00:00, 61.54step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:   0% 0/103 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:   8% 8/103 [00:00<00:01, 72.40step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  23% 24/103 [00:00<00:01, 76.75step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  31% 32/103 [00:00<00:00, 71.57step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  39% 40/103 [00:00<00:00, 66.99step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  46% 47/103 [00:00<00:00, 59.65step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  52% 54/103 [00:00<00:00, 54.93step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  58% 60/103 [00:01<00:00, 47.89step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  63% 65/103 [00:01<00:00, 43.23step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  68% 70/103 [00:01<00:00, 41.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_93:  72% 63/87 [00:01<00:00, 36.36step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  73% 75/103 [00:01<00:00, 36.24step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  77% 79/103 [00:01<00:00, 36.21step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  81% 83/103 [00:01<00:00, 35.70step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  84% 87/103 [00:01<00:00, 34.12step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  88% 91/103 [00:01<00:00, 34.29step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_93: 100% 87/87 [00:02<00:00, 36.28step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_94: 100% 87/87 [00:02<00:00, 36.28step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  92% 95/103 [00:02<00:00, 33.36step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_43:  96% 99/103 [00:02<00:00, 33.49step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:   0% 0/95 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:   7% 7/95 [00:00<00:01, 63.04step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  24% 23/95 [00:00<00:01, 70.81step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  33% 31/95 [00:00<00:00, 71.82step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  41% 39/95 [00:00<00:00, 65.78step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  48% 46/95 [00:00<00:00, 56.80step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  55% 52/95 [00:00<00:00, 47.71step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  61% 58/95 [00:01<00:00, 42.29step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_94:  76% 66/87 [00:01<00:00, 36.28step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  66% 63/95 [00:01<00:00, 39.27step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  72% 68/95 [00:01<00:00, 37.22step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  76% 72/95 [00:01<00:00, 36.60step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  80% 76/95 [00:01<00:00, 35.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_94:  99% 86/87 [00:01<00:00, 36.16step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_95: 100% 87/87 [00:02<00:00, 36.16step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  84% 80/95 [00:01<00:00, 35.12step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  88% 84/95 [00:01<00:00, 34.11step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_44:  93% 88/95 [00:02<00:00, 34.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45: 100% 95/95 [00:02<00:00, 35.71step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:   9% 8/89 [00:00<00:01, 74.37step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  27% 24/89 [00:00<00:00, 77.52step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  36% 32/89 [00:00<00:00, 74.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  45% 40/89 [00:00<00:00, 66.69step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  53% 47/89 [00:00<00:00, 54.60step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_95:  72% 64/89 [00:01<00:00, 40.66step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  60% 53/89 [00:00<00:00, 46.32step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  65% 58/89 [00:01<00:00, 42.01step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  71% 63/89 [00:01<00:00, 37.10step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  75% 67/89 [00:01<00:00, 36.37step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_95:  98% 87/89 [00:01<00:00, 37.84step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  80% 71/89 [00:01<00:00, 36.19step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_96:   0% 0/88 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  84% 75/89 [00:01<00:00, 34.35step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  89% 79/89 [00:01<00:00, 34.47step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_45:  93% 83/89 [00:01<00:00, 34.22step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:   0% 0/87 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  18% 16/87 [00:00<00:00, 73.47step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  28% 24/87 [00:00<00:00, 69.43step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  44% 38/87 [00:00<00:01, 48.19step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_96:  61% 54/88 [00:01<00:01, 30.31step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  51% 44/87 [00:00<00:01, 36.09step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  56% 49/87 [00:01<00:01, 28.93step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_96:  74% 65/88 [00:01<00:00, 23.98step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  61% 53/87 [00:01<00:01, 24.77step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  64% 56/87 [00:01<00:01, 23.19step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  68% 59/87 [00:01<00:01, 21.39step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  71% 62/87 [00:01<00:01, 20.15step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_96:  91% 80/88 [00:02<00:00, 19.37step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  75% 65/87 [00:02<00:01, 19.34step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  78% 68/87 [00:02<00:00, 20.82step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  82% 71/87 [00:02<00:00, 21.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_97: 100% 88/88 [00:03<00:00, 19.32step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  85% 74/87 [00:02<00:00, 20.63step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  89% 77/87 [00:02<00:00, 20.78step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_97:  10% 10/99 [00:00<00:01, 45.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  92% 80/87 [00:02<00:00, 20.68step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_46:  95% 83/87 [00:02<00:00, 22.31step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:   0% 0/88 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:   9% 8/88 [00:00<00:01, 64.66step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  25% 22/88 [00:00<00:01, 56.78step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  32% 28/88 [00:00<00:01, 56.93step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_97:  42% 42/99 [00:01<00:02, 28.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  39% 34/88 [00:00<00:01, 42.51step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  44% 39/88 [00:00<00:01, 34.73step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  49% 43/88 [00:01<00:01, 27.07step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_97:  55% 54/99 [00:01<00:02, 20.44step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  53% 47/88 [00:01<00:01, 23.55step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  58% 51/88 [00:01<00:01, 24.73step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  61% 54/88 [00:01<00:01, 22.29step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_97:  65% 64/99 [00:02<00:01, 18.81step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  65% 57/88 [00:01<00:01, 20.68step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  68% 60/88 [00:02<00:01, 19.59step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  72% 63/88 [00:02<00:01, 20.70step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_97:  74% 73/99 [00:02<00:01, 19.91step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  78% 69/88 [00:02<00:00, 21.12step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  82% 72/88 [00:02<00:00, 22.82step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  85% 75/88 [00:02<00:00, 23.81step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  89% 78/88 [00:02<00:00, 23.63step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  92% 81/88 [00:02<00:00, 24.21step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_97:  95% 94/99 [00:03<00:00, 27.56step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  95% 84/88 [00:03<00:00, 21.35step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_98: 100% 99/99 [00:03<00:00, 29.18step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_47:  99% 87/88 [00:03<00:00, 22.05step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:   0% 0/96 [00:00<?, ?step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:   7% 7/96 [00:00<00:01, 63.71step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  24% 23/96 [00:00<00:00, 74.53step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  32% 31/96 [00:00<00:00, 70.74step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  41% 39/96 [00:00<00:00, 62.04step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  48% 46/96 [00:00<00:00, 54.72step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  54% 52/96 [00:00<00:00, 45.35step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  59% 57/96 [00:01<00:00, 41.71step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  65% 62/96 [00:01<00:00, 38.00step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  69% 66/96 [00:01<00:00, 37.19step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  73% 70/96 [00:01<00:00, 36.36step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  77% 74/96 [00:01<00:00, 36.07step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  81% 78/96 [00:01<00:00, 35.57step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  85% 82/96 [00:01<00:00, 32.14step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_98:  99% 83/84 [00:02<00:00, 33.74step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_99: 100% 84/84 [00:02<00:00, 33.74step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  90% 86/96 [00:01<00:00, 32.83step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  94% 90/96 [00:02<00:00, 32.97step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_48:  98% 94/96 [00:02<00:00, 34.03step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:   8% 7/88 [00:00<00:01, 68.11step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:  17% 15/88 [00:00<00:01, 72.06step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:  35% 31/88 [00:00<00:00, 66.80step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:  43% 38/88 [00:00<00:00, 52.34step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_99:  60% 51/85 [00:01<00:00, 39.26step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:  50% 44/88 [00:00<00:01, 42.51step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:  56% 49/88 [00:01<00:00, 39.42step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:  61% 54/88 [00:01<00:00, 36.88step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:  66% 58/88 [00:01<00:00, 35.70step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:  70% 62/88 [00:01<00:00, 34.95step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:  75% 66/88 [00:01<00:00, 33.08step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49:  80% 70/88 [00:01<00:00, 32.30step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_99:  99% 84/85 [00:02<00:00, 33.38step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Replaying traj_49: 100% 88/88 [00:02<00:00, 42.00step/s, control_mode=pd_ee_delta_pose, obs_mode=state]
# Merge to demos/v0/rigid_body/LiftCube-v0/trajectory.state.pd_ee_delta_pose.h5
# Merging demos/v0/rigid_body/LiftCube-v0/trajectory.state.pd_ee_delta_pose.0.h5
# Merging demos/v0/rigid_body/LiftCube-v0/trajectory.state.pd_ee_delta_pose.1.h5
# Remove demos/v0/rigid_body/LiftCube-v0/trajectory.state.pd_ee_delta_pose.0.h5
# Remove demos/v0/rigid_body/LiftCube-v0/trajectory.state.pd_ee_delta_pose.0.json
# Remove demos/v0/rigid_body/LiftCube-v0/trajectory.state.pd_ee_delta_pose.1.h5
# Remove demos/v0/rigid_body/LiftCube-v0/trajectory.state.pd_ee_delta_pose.1.json

# %% [markdown]
# # 2. Dataset
# Here we are initializing the dataset and reading from the saved trajectories we created in the previous step.

# %%
def load_h5_data(data):
    out = dict()
    for k in data.keys():
        if isinstance(data[k], h5py.Dataset):
            out[k] = data[k][:]
        else:
            out[k] = load_h5_data(data[k])
    return out


class ManiSkill2Dataset(Dataset):
    def __init__(self, dataset_file: str, load_count=-1) -> None:
        self.dataset_file = dataset_file
        # for details on how the code below works, see the
        # quick start tutorial
        import h5py
        from mani_skill2.utils.io_utils import load_json

        self.data = h5py.File(dataset_file, "r")
        json_path = dataset_file.replace(".h5", ".json")
        self.json_data = load_json(json_path)
        self.episodes = self.json_data["episodes"]

        self.env_info = self.json_data["env_info"]
        self.env_id = self.env_info["env_id"]
        self.env_kwargs = self.env_info["env_kwargs"]

        self.observations = []
        self.actions = []
        self.rewards = []
        self.dones = []
        self.total_frames = 0
        if load_count == -1:
            load_count = len(self.episodes)
        for eps_id in tqdm(range(load_count)):
            eps = self.episodes[eps_id]
            trajectory = self.data[f"traj_{eps['episode_id']}"]
            trajectory = load_h5_data(trajectory)

            # we use :-1 here to ignore the last observation as that
            # is the terminal observation which has no actions
            self.observations.append(trajectory["obs"][:-1])
            self.actions.append(trajectory["actions"])
            self.rewards.append(trajectory["rewards"][1:])
            self.dones.append(trajectory["success"])
            # print(trajectory.keys())

        # self.rewards = np.vstack(self.rewards)

    def get_state_stats(self):
        arr = np.vstack(self.observations)
        return np.mean(arr, axis=0), np.std(arr, axis=0) + 1e-6

    def __len__(self):
        return len(self.observations)

    def __getitem__(self, idx):
        action = torch.from_numpy(self.actions[idx]).float()
        obs = torch.from_numpy(self.observations[idx]).float()
        rew = torch.from_numpy(self.rewards[idx]).float()
        done = torch.from_numpy(self.dones[idx]).float()
        return obs, action, rew, done

# %%
dataset = ManiSkill2Dataset(
    f"demos/v0/rigid_body/{env_id}/trajectory.state.pd_ee_delta_pose.h5"
)
# quick check that the env is configured correctly
assert env.action_space.shape[0] == dataset[0][1].shape[-1]
# Out:
#   0%|          | 0/98 [00:00<?, ?it/s]

# %%
len(dataset)
# Out:
# 98

# %% [markdown]
# # 2. Define load batch
# Now that we loaded our dataset into the `dataset`variable we now define a custom `load_batch` function that splits the data into batches as well as performs such preprocessing steps. Decision transformers uses 3 inputs, namely state, action, and returns-to-go.
#
# While the other two are already defined in the dataset, the last one needs to be computed from the rewards. Returns-to-go represents the expected future rewards and it is computed by taking the sum of the rewards from a certain timestep forwards. For example, if we are at timestep 1 we can compute the returns-to-go by summing up the rewards from timestep 2 to the end of the batch. This is implemented in `discounted_cumsum`.

# %%
def discount_cumsum(x, gamma):
    discount_cumsum = np.zeros_like(x)
    discount_cumsum[-1] = x[-1]
    for t in reversed(range(x.shape[0] - 1)):
        discount_cumsum[t] = x[t] + gamma * discount_cumsum[t + 1]
    return discount_cumsum

# %%
def load_batch(
    batch_size=16,
    max_len=20,
    num_trajectories=100,
    state_dim=42,
    act_dim=7,
    max_ep_len=90,
    scale=50,
):
    batch_inds = np.random.choice(
        np.arange(num_trajectories),
        size=batch_size,
        replace=True,
    )
    state_mean, state_std = dataset.get_state_stats()
    s, a, r, d, rtg, timesteps, mask = [], [], [], [], [], [], []
    for i in range(batch_size):
        obs, action, rew, done = dataset[batch_inds[i]]
        si = random.randint(0, rew.shape[0] - 1 - max_len)
        s.append(obs[si : si + max_len].reshape(1, -1, state_dim))
        a.append(action[si : si + max_len].reshape(1, -1, act_dim))
        r.append(rew[si : si + max_len].reshape(1, -1, 1))
        d.append(done[si : si + max_len].reshape(1, -1))
        timesteps.append(np.arange(si, si + s[-1].shape[1]).reshape(1, -1))
        timesteps[-1][timesteps[-1] >= max_ep_len] = max_ep_len - 1
        rtg.append(
            discount_cumsum(rew[si:], gamma=1.0)[: s[-1].shape[1] + 1].reshape(1, -1, 1)
        )
        tlen = s[-1].shape[1]
        s[-1] = np.concatenate(
            [np.zeros((1, max_len - tlen, state_dim)), s[-1]], axis=1
        )
        s[-1] = (s[-1] - state_mean) / state_std
        a[-1] = np.concatenate(
            [np.ones((1, max_len - tlen, act_dim)) * -10.0, a[-1]], axis=1
        )
        r[-1] = np.concatenate([np.zeros((1, max_len - tlen, 1)), r[-1]], axis=1)
        d[-1] = np.concatenate([np.ones((1, max_len - tlen)) * 2, d[-1]], axis=1)
        rtg[-1] = np.concatenate([np.zeros((1, max_len - tlen, 1)), rtg[-1]], axis=1)
        timesteps[-1] = np.concatenate(
            [np.zeros((1, max_len - tlen)), timesteps[-1]], axis=1
        )
        mask.append(
            np.concatenate([np.zeros((1, max_len - tlen)), np.ones((1, tlen))], axis=1)
        )

    device = "cuda:0"
    s = torch.from_numpy(np.concatenate(s, axis=0)).to(
        dtype=torch.float32, device=device
    )
    a = torch.from_numpy(np.concatenate(a, axis=0)).to(
        dtype=torch.float32, device=device
    )
    r = torch.from_numpy(np.concatenate(r, axis=0)).to(
        dtype=torch.float32, device=device
    )
    d = torch.from_numpy(np.concatenate(d, axis=0)).to(dtype=torch.long, device=device)
    rtg = torch.from_numpy(np.concatenate(rtg, axis=0)).to(
        dtype=torch.float32, device=device
    )
    timesteps = torch.from_numpy(np.concatenate(timesteps, axis=0)).to(
        dtype=torch.long, device=device
    )
    mask = torch.from_numpy(np.concatenate(mask, axis=0)).to(device=device)
    return s, a, r, d, rtg, timesteps, mask

# %% [markdown]
# #3. Define model
# The actual reinforcement model uses the basic decoder only architecture seen in models like `GPT-2`. In fact this implementation uses a modified version of the `GPT-2` model with a few extra additions.
#
# Decision transformer works by taking in the three inputs and then running them through a linear layer that is analogous to the embedding that text tokens go through in a language transformer. We also have a position embedding based on the the timestep. The time step is then added to each of these embeddigs. These three embeddings are then interleaved together such that one timestep is made up of 3 tokens. This input is then fed into `gpt 2`. The hidden states from `gpt 2` are then fed through two different linear layers to obtain state (not used) and action predictions.
#
# There is additional code that then takes this action predictions to obtain an action.

# %%
from transformers import GPT2Model, GPT2Config


class DecisionTransformer(nn.Module):
    def __init__(
        self,
        state_dim,
        act_dim,
        hidden_size,
        max_length=None,
        max_ep_len=4096,
        **kwargs
    ):
        super().__init__()
        config = GPT2Config(vocab_size=1, n_embd=hidden_size, **kwargs)
        self.transformer = GPT2Model(config)
        self.state_dim = state_dim
        self.act_dim = act_dim
        self.max_length = max_length
        self.embed_timestep = nn.Embedding(max_ep_len, hidden_size)
        self.embed_return = torch.nn.Linear(1, hidden_size)
        self.embed_state = torch.nn.Linear(self.state_dim, hidden_size)
        self.embed_action = torch.nn.Linear(self.act_dim, hidden_size)
        self.hidden_size = hidden_size
        self.embed_ln = nn.LayerNorm(hidden_size)
        self.predict_state = torch.nn.Linear(hidden_size, self.state_dim)
        self.predict_action = nn.Sequential(
            *([nn.Linear(hidden_size, self.act_dim), nn.Tanh()])
        )
        self.predict_return = torch.nn.Linear(hidden_size, 1)

    def forward(self, states, actions, rewards, rtg, timesteps, attention_mask):

        batch_size, seq_length = states.shape[0], states.shape[1]

        if attention_mask is None:
            # attention mask for GPT: 1 if can be attended to, 0 if not
            attention_mask = torch.ones((batch_size, seq_length), dtype=torch.long)

        # embed each modality with a different head
        state_embeddings = self.embed_state(states)
        action_embeddings = self.embed_action(actions)
        returns_embeddings = self.embed_return(rtg)
        time_embeddings = self.embed_timestep(timesteps)

        # time embeddings are treated similar to positional embeddings
        state_embeddings = state_embeddings + time_embeddings
        action_embeddings = action_embeddings + time_embeddings
        returns_embeddings = returns_embeddings + time_embeddings

        # this makes the sequence look like (R_1, s_1, a_1, R_2, s_2, a_2, ...)
        # which works nice in an autoregressive sense since states predict actions
        stacked_inputs = (
            torch.stack(
                (returns_embeddings, state_embeddings, action_embeddings), dim=1
            )
            .permute(0, 2, 1, 3)
            .reshape(batch_size, 3 * seq_length, self.hidden_size)
        )
        stacked_inputs = self.embed_ln(stacked_inputs)

        # to make the attention mask fit the stacked inputs, have to stack it as well
        stacked_attention_mask = (
            torch.stack((attention_mask, attention_mask, attention_mask), dim=1)
            .permute(0, 2, 1)
            .reshape(batch_size, 3 * seq_length)
        )

        # we feed in the input embeddings (not word indices as in NLP) to the model
        transformer_outputs = self.transformer(
            inputs_embeds=stacked_inputs,
            attention_mask=stacked_attention_mask,
        )
        x = transformer_outputs["last_hidden_state"]

        # reshape x so that the second dimension corresponds to the original
        # returns (0), states (1), or actions (2); i.e. x[:,1,t] is the token for s_t
        x = x.reshape(batch_size, seq_length, 3, self.hidden_size).permute(0, 2, 1, 3)

        # get predictions
        action_preds = self.predict_action(x[:, 1])  # predict next action given state
        state_preds = self.predict_state(x[:, 2])
        return_preds = self.predict_return(x[:, 2])

        return state_preds, action_preds, return_preds

    def get_action(self, states, actions, rewards, returns_to_go, timesteps, **kwargs):
        # we don't care about the past rewards in this model

        states = states.reshape(1, -1, self.state_dim)
        actions = actions.reshape(1, -1, self.act_dim)
        returns_to_go = returns_to_go.reshape(1, -1, 1)
        timesteps = timesteps.reshape(1, -1)

        if self.max_length is not None:
            states = states[:, -self.max_length :]
            actions = actions[:, -self.max_length :]
            returns_to_go = returns_to_go[:, -self.max_length :]
            timesteps = timesteps[:, -self.max_length :]

            # pad all tokens to sequence length
            attention_mask = torch.cat(
                [
                    torch.zeros(self.max_length - states.shape[1]),
                    torch.ones(states.shape[1]),
                ]
            )
            attention_mask = attention_mask.to(
                dtype=torch.long, device=states.device
            ).reshape(1, -1)
            states = torch.cat(
                [
                    torch.zeros(
                        (
                            states.shape[0],
                            self.max_length - states.shape[1],
                            self.state_dim,
                        ),
                        device=states.device,
                    ),
                    states,
                ],
                dim=1,
            ).to(dtype=torch.float32)
            actions = torch.cat(
                [
                    torch.zeros(
                        (
                            actions.shape[0],
                            self.max_length - actions.shape[1],
                            self.act_dim,
                        ),
                        device=actions.device,
                    ),
                    actions,
                ],
                dim=1,
            ).to(dtype=torch.float32)
            returns_to_go = torch.cat(
                [
                    torch.zeros(
                        (
                            returns_to_go.shape[0],
                            self.max_length - returns_to_go.shape[1],
                            1,
                        ),
                        device=returns_to_go.device,
                    ),
                    returns_to_go,
                ],
                dim=1,
            ).to(dtype=torch.float32)
            timesteps = torch.cat(
                [
                    torch.zeros(
                        (timesteps.shape[0], self.max_length - timesteps.shape[1]),
                        device=timesteps.device,
                    ),
                    timesteps,
                ],
                dim=1,
            ).to(dtype=torch.long)
        else:
            attention_mask = None

        _, action_preds, return_preds = self.forward(
            states,
            actions,
            None,
            returns_to_go,
            timesteps,
            attention_mask=attention_mask,
            **kwargs
        )

        return action_preds[0, -1]

# %% [markdown]
# #4. Define trainer
# Here we define a trainer parent class and a sequence trainer child class to help train the model. This trainer contains details such as the optimizer, loss, and learning rate scheduler.

# %%
import time


class Trainer:
    def __init__(
        self,
        model,
        optimizer,
        batch_size,
        get_batch,
        loss_fn,
        scheduler=None,
        eval_fns=None,
        state_dim=None,
    ):
        self.model = model
        self.optimizer = optimizer
        self.batch_size = batch_size
        self.get_batch = get_batch
        self.loss_fn = loss_fn
        self.scheduler = scheduler
        self.eval_fns = [] if eval_fns is None else eval_fns
        self.diagnostics = dict()
        self.state_dim = state_dim
        self.start_time = time.time()

    def train_iteration(self, num_steps, iter_num=0, print_logs=False):

        train_losses = []
        logs = dict()

        train_start = time.time()

        self.model.train()
        for _ in range(num_steps):
            train_loss = self.train_step()
            train_losses.append(train_loss)
            if self.scheduler is not None:
                self.scheduler.step()

        logs["time/training"] = time.time() - train_start

        eval_start = time.time()

        self.model.eval()
        for eval_fn in self.eval_fns:
            outputs = eval_fn(self.model)
            for k, v in outputs.items():
                logs[f"evaluation/{k}"] = v

        logs["time/total"] = time.time() - self.start_time
        logs["time/evaluation"] = time.time() - eval_start
        logs["training/train_loss_mean"] = np.mean(train_losses)
        logs["training/train_loss_std"] = np.std(train_losses)

        for k in self.diagnostics:
            logs[k] = self.diagnostics[k]

        if print_logs:
            print("=" * 80)
            print(f"Iteration {iter_num}")
            for k, v in logs.items():
                print(f"{k}: {v}")

        return logs

    def train_step(self):
        states, actions, rewards, dones, attention_mask, returns = self.get_batch(
            self.batch_size, state_dim=self.state_dim
        )
        state_target, action_target, reward_target = (
            torch.clone(states),
            torch.clone(actions),
            torch.clone(rewards),
        )

        state_preds, action_preds, reward_preds = self.model.forward(
            states,
            actions,
            rewards,
            masks=None,
            attention_mask=attention_mask,
            target_return=returns,
        )

        # note: currently indexing & masking is not fully correct
        loss = self.loss_fn(
            state_preds,
            action_preds,
            reward_preds,
            state_target[:, 1:],
            action_target,
            reward_target[:, 1:],
        )
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        return loss.detach().cpu().item()


class SequenceTrainer(Trainer):
    def train_step(self):
        (
            states,
            actions,
            rewards,
            dones,
            rtg,
            timesteps,
            attention_mask,
        ) = self.get_batch(self.batch_size, state_dim=self.state_dim)
        action_target = torch.clone(actions)

        state_preds, action_preds, reward_preds = self.model.forward(
            states,
            actions,
            rewards,
            rtg[:, :-1],
            timesteps,
            attention_mask=attention_mask,
        )

        act_dim = action_preds.shape[2]
        action_preds = action_preds.reshape(-1, act_dim)[attention_mask.reshape(-1) > 0]
        action_target = action_target.reshape(-1, act_dim)[
            attention_mask.reshape(-1) > 0
        ]

        loss = self.loss_fn(
            None,
            action_preds,
            None,
            None,
            action_target,
            None,
        )

        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), 0.25)
        self.optimizer.step()

        with torch.no_grad():
            self.diagnostics["training/action_error"] = (
                torch.mean((action_preds - action_target) ** 2).detach().cpu().item()
            )

        return loss.detach().cpu().item()

# %% [markdown]
# # 5. Define variables and initialize model
# Here we define the hyperparameters and other parameters needed for the model and training. Many of these specify variables for the transformer such as the embed dimension and the number of layers, while others specify variables for the loss or learning rate scheduler.

# %%
variant = {
    "embed_dim": 256,
    "n_layer": 4,
    "n_head": 1,
    "dropout": 0.1,
    "activation_function": "relu",
    "warmup_steps": 10_000,
    "learning_rate": 1e-4,
    "weight_decay": 1e-4,
    "max_iters": 15,
    "K": 30,
    "max_ep_len": 100,
    "num_eval_episodes": 100,
}
K = variant["K"]
state_dim = env.observation_space.shape[0]
act_dim = env.action_space.shape[0]
max_ep_len = variant["max_ep_len"]
num_eval_episodes = variant["num_eval_episodes"]
state_mean, state_std = dataset.get_state_stats()

# %%
model = DecisionTransformer(
    state_dim=state_dim,
    act_dim=act_dim,
    max_length=K,
    max_ep_len=100,
    hidden_size=variant["embed_dim"],
    n_layer=variant["n_layer"],
    n_head=variant["n_head"],
    n_inner=4 * variant["embed_dim"],
    activation_function=variant["activation_function"],
    n_positions=1024,
    resid_pdrop=variant["dropout"],
    attn_pdrop=variant["dropout"],
)
model = model.to(device="cuda:0")

# %% [markdown]
# #6. Create eval function
# Here we define the evaluation functions to test how the model runs. This method comes in two fold with the `evaluate_episode_rtg` performing the evaluation for individual episodes. This method is then called in `eval_episdoes` which runs `evaluate_episode_rtg` a number of times. This latter function is also used to log some key statistics about this evaluation like the success rate and mean reward.

# %%
def evaluate_episode_rtg(
    env,
    state_dim,
    act_dim,
    model,
    max_ep_len=100,
    scale=10.0,
    state_mean=0.0,
    state_std=1.0,
    device="cuda:0",
    target_return=None,
    mode="normal",
):

    model.eval()
    model.to(device=device)

    state_mean = torch.from_numpy(state_mean).to(device=device)
    state_std = torch.from_numpy(state_std).to(device=device)

    state = env.reset()[0]
    if mode == "noise":
        state = state + np.random.normal(0, 0.1, size=state.shape)

    # we keep all the histories on the device
    # note that the latest action and reward will be "padding"
    states = (
        torch.from_numpy(state)
        .reshape(1, state_dim)
        .to(device=device, dtype=torch.float32)
    )
    actions = torch.zeros((0, act_dim), device=device, dtype=torch.float32)
    rewards = torch.zeros(0, device=device, dtype=torch.float32)

    ep_return = target_return
    target_return = torch.tensor(ep_return, device=device, dtype=torch.float32).reshape(
        1, 1
    )
    timesteps = torch.tensor(0, device=device, dtype=torch.long).reshape(1, 1)

    sim_states = []

    episode_return, episode_length = 0, 0
    for t in range(max_ep_len):

        # add padding
        actions = torch.cat([actions, torch.zeros((1, act_dim), device=device)], dim=0)
        rewards = torch.cat([rewards, torch.zeros(1, device=device)])

        action = model.get_action(
            (states.to(dtype=torch.float32) - state_mean) / state_std,
            actions.to(dtype=torch.float32),
            rewards.to(dtype=torch.float32),
            target_return.to(dtype=torch.float32),
            timesteps.to(dtype=torch.long),
        )
        actions[-1] = action
        action = action.detach().cpu().numpy()

        state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated

        cur_state = torch.from_numpy(state).to(device=device).reshape(1, state_dim)
        states = torch.cat([states, cur_state], dim=0)
        rewards[-1] = reward

        if mode != "delayed":
            pred_return = target_return[0, -1] - (reward / scale)
        else:
            pred_return = target_return[0, -1]
        target_return = torch.cat([target_return, pred_return.reshape(1, 1)], dim=1)
        timesteps = torch.cat(
            [timesteps, torch.ones((1, 1), device=device, dtype=torch.long) * (t + 1)],
            dim=1,
        )

        episode_return += reward
        episode_length += 1

        # if done:
        #     break
    success = info["success"]

    return episode_return, episode_length, success

# %%
def eval_episodes(target_rew):
    def fn(model):
        returns, lengths = [], []
        success = 0
        for _ in range(num_eval_episodes):
            with torch.no_grad():
                ret, length, s = evaluate_episode_rtg(
                    env,
                    state_dim,
                    act_dim,
                    model,
                    max_ep_len=max_ep_len,
                    scale=10,
                    target_return=target_rew / 10,
                    mode="normal",
                    state_mean=state_mean,
                    state_std=state_std,
                    device="cuda:0",
                )
            returns.append(ret)
            lengths.append(length)
            success += s
        return {
            f"target_{target_rew}_return_mean": np.mean(returns),
            f"target_{target_rew}_return_std": np.std(returns),
            f"target_{target_rew}_length_mean": np.mean(lengths),
            f"target_{target_rew}_length_std": np.std(lengths),
            f"target_{target_rew}_success_rate": success / len(returns),
        }

    return fn

# %% [markdown]
# #7. Instantiate optimizer, scheduler, wandb and trainer
# Here we instantiate the optimizer, scheduler and trainer objects to be used in the next step.
# Using Wandb for logging can also be toggled on, but it requires an api key from Wandb.

# %%
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=variant["learning_rate"],
    weight_decay=variant["weight_decay"],
)
scheduler = torch.optim.lr_scheduler.LambdaLR(
    optimizer, lambda steps: min((steps + 1) / variant["warmup_steps"], 1)
)

trainer = SequenceTrainer(
    model=model,
    optimizer=optimizer,
    batch_size=32,
    get_batch=load_batch,
    scheduler=scheduler,
    loss_fn=lambda s_hat, a_hat, r_hat, s, a, r: torch.mean((a_hat - a) ** 2),
    eval_fns=[eval_episodes(tar) for tar in [50, 25]],
    state_dim=state_dim,
)

# %%
use_wandb = False  # @param {type:"boolean"}
if use_wandb:
    wandb.init(
        name=f"maniskill2-{env_id}-{random.randint(0, 100000)}",
        group=f"maniskill2-{env_id}",
        project="decision-transformer",
        config=variant,
    )

# %% [markdown]
# # 8. Train the Model

# %%
for iter in range(variant["max_iters"]):
    outputs = trainer.train_iteration(1000, iter_num=iter, print_logs=True)
    if use_wandb:
        wandb.log(outputs)
# Out:
# ================================================================================
# Iteration 0
# time/training: 129.9936866760254
# evaluation/target_50_return_mean: 8.628591140859395
# evaluation/target_50_return_std: 2.3996948189285146
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 8.964036443337456
# evaluation/target_25_return_std: 2.9256796689606714
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 399.8114821910858
# time/evaluation: 220.05823349952698
# training/train_loss_mean: 0.13538279953598975
# training/train_loss_std: 0.1235495622643161
# training/action_error: 0.01846698857843876
# ================================================================================
# Iteration 1
# time/training: 126.23758864402771
# evaluation/target_50_return_mean: 12.202699902284937
# evaluation/target_50_return_std: 4.24248125644988
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 11.718804509514962
# evaluation/target_25_return_std: 3.6696348925359397
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 766.886923789978
# time/evaluation: 240.82545638084412
# training/train_loss_mean: 0.01008290187921375
# training/train_loss_std: 0.003104878210495232
# training/action_error: 0.007617974188178778
# ================================================================================
# Iteration 2
# time/training: 125.42901706695557
# evaluation/target_50_return_mean: 11.671495906583495
# evaluation/target_50_return_std: 2.7179420144053443
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 11.78711219898203
# evaluation/target_25_return_std: 3.109418118468471
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 1111.8976910114288
# time/evaluation: 219.56959509849548
# training/train_loss_mean: 0.005011260039405897
# training/train_loss_std: 0.0016793476860091812
# training/action_error: 0.006498965434730053
# ================================================================================
# Iteration 3
# time/training: 126.24728322029114
# evaluation/target_50_return_mean: 13.259652027107869
# evaluation/target_50_return_std: 4.770956178242393
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 13.370698486604622
# evaluation/target_25_return_std: 5.099100757083417
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 1479.6880793571472
# time/evaluation: 241.53850197792053
# training/train_loss_mean: 0.0030637755919015034
# training/train_loss_std: 0.001321446716787466
# training/action_error: 0.0015189873520284891
# ================================================================================
# Iteration 4
# time/training: 126.10633111000061
# evaluation/target_50_return_mean: 13.361585213586398
# evaluation/target_50_return_std: 5.217010127538421
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 13.828435511777366
# evaluation/target_25_return_std: 5.683108077539269
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 1850.0753574371338
# time/evaluation: 244.26001596450806
# training/train_loss_mean: 0.0024421895713894626
# training/train_loss_std: 0.0012256522460119671
# training/action_error: 0.0012274176115170121
# ================================================================================
# Iteration 5
# time/training: 125.72971630096436
# evaluation/target_50_return_mean: 12.762105893529984
# evaluation/target_50_return_std: 3.7813637820112675
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 12.814039749255507
# evaluation/target_25_return_std: 4.077982539188559
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 2203.9390563964844
# time/evaluation: 228.1055302619934
# training/train_loss_mean: 0.0021858491915627385
# training/train_loss_std: 0.0011725775518867645
# training/action_error: 0.0020595858804881573
# ================================================================================
# Iteration 6
# time/training: 125.13768672943115
# evaluation/target_50_return_mean: 15.745683969346125
# evaluation/target_50_return_std: 5.884522350887395
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 15.089675467683698
# evaluation/target_25_return_std: 6.030726486403662
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 2569.2497658729553
# time/evaluation: 240.16688013076782
# training/train_loss_mean: 0.0018802352072380018
# training/train_loss_std: 0.0010342240821803155
# training/action_error: 0.0014439810765907168
# ================================================================================
# Iteration 7
# time/training: 124.38961982727051
# evaluation/target_50_return_mean: 10.909968065102142
# evaluation/target_50_return_std: 0.8669621005699658
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 10.834313169708507
# evaluation/target_25_return_std: 0.950534856430609
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 2903.7528159618378
# time/evaluation: 210.08445692062378
# training/train_loss_mean: 0.001478917056840146
# training/train_loss_std: 0.0009056837057581738
# training/action_error: 0.0024688735138624907
# ================================================================================
# Iteration 8
# time/training: 123.76972079277039
# evaluation/target_50_return_mean: 12.314868849837602
# evaluation/target_50_return_std: 3.9181734883981063
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 12.467547237390306
# evaluation/target_25_return_std: 4.087247215863504
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 3261.808940410614
# time/evaluation: 234.2797396183014
# training/train_loss_mean: 0.001263379322903347
# training/train_loss_std: 0.0007768684327989054
# training/action_error: 0.0010908592958003283
# ================================================================================
# Iteration 9
# time/training: 125.54318976402283
# evaluation/target_50_return_mean: 13.53214903268215
# evaluation/target_50_return_std: 5.399209911020825
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 13.746305174660915
# evaluation/target_25_return_std: 5.262646750087461
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 3616.7230513095856
# time/evaluation: 229.3516194820404
# training/train_loss_mean: 0.0010165647696194356
# training/train_loss_std: 0.0007000189064459341
# training/action_error: 0.0004796972789335996
# ================================================================================
# Iteration 10
# time/training: 124.37558960914612
# evaluation/target_50_return_mean: 11.510917845828072
# evaluation/target_50_return_std: 3.493271387953005
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 12.170352406271919
# evaluation/target_25_return_std: 3.767027280928139
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 3953.1294782161713
# time/evaluation: 212.01528191566467
# training/train_loss_mean: 0.000786098250609939
# training/train_loss_std: 0.0005967547530570325
# training/action_error: 0.0016004662029445171
# ================================================================================
# Iteration 11
# time/training: 124.16683530807495
# evaluation/target_50_return_mean: 11.894966159640116
# evaluation/target_50_return_std: 3.1793273962475257
# evaluation/target_50_length_mean: 100.0
# evaluation/target_50_length_std: 0.0
# evaluation/target_50_success_rate: 0.0
# evaluation/target_25_return_mean: 11.788426924190276
# evaluation/target_25_return_std: 3.6152432239798684
# evaluation/target_25_length_mean: 100.0
# evaluation/target_25_length_std: 0.0
# evaluation/target_25_success_rate: 0.0
# time/total: 4297.503741264343
# time/evaluation: 220.19145917892456
# training/train_loss_mean: 0.0007021591333614196
# training/train_loss_std: 0.0005718490330677281
# training/action_error: 0.000329564674757421

# %% [markdown]
# # 9. Saving model weights and a video
# Here we use Mani-Skill2's video functionality to record a video of the model in action.
# There is also code to save the model weights fro later use.

# %%
from mani_skill2.utils.wrappers import RecordEpisode

video_env = RecordEpisode(
    gym.make(
        env_id,
        render_mode="cameras",
        enable_shadow=True,
        obs_mode="state",
        control_mode="pd_ee_delta_pose",
    ),
    "./videos",
    info_on_video=True,
)
out = evaluate_episode_rtg(
    video_env,
    state_dim,
    act_dim,
    model,
    target_return=50,
    state_mean=dataset.get_state_stats()[0],
    state_std=dataset.get_state_stats()[1],
)
video_env.flush_video()
if use_wandb:
    wandb.log({f"video_{env_id}": wandb.Video("./videos/0.mp4")})
from IPython.display import Video

Video("./videos/0.mp4", embed=True)

# %%
torch.save(model.state_dict(), os.path.join(wandb.run.dir, f"weights_{env_id}.pt"))
if use_wandb:
    wandb.save(f"weights_{env_id}.pt")
